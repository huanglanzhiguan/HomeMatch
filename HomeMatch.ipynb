# %% [markdown]
# # Step 1: Setting Up the Python Application

# %%
# !pip install chromadb
# !pip install langchain
# !pip install langchain-openai
# !pip install numpy
# !pip install openai
# !pip install pandas
# !pip install pydantic
# Out:
# Requirement already satisfied: chromadb in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (0.4.14)
# Requirement already satisfied: requests>=2.28 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from chromadb) (2.31.0)
# Requirement already satisfied: pydantic>=1.9 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from chromadb) (2.5.3)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from chromadb) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from chromadb) (0.103.0)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.30.6)
# Requirement already satisfied: posthog>=2.4.0 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from chromadb) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from chromadb) (4.11.0)
# Requirement already satisfied: pulsar-client>=3.1.0 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from chromadb) (3.5.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from chromadb) (1.18.1)
# Requirement already satisfied: tokenizers>=0.13.2 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from chromadb) (0.20.0)
# Requirement already satisfied: pypika>=0.48.9 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from chromadb) (4.65.0)
# Requirement already satisfied: overrides>=7.3.1 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from chromadb) (7.4.0)
# Requirement already satisfied: importlib-resources in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from chromadb) (6.4.0)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from chromadb) (1.65.4)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from chromadb) (4.2.0)
# Requirement already satisfied: typer>=0.9.0 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from chromadb) (0.12.3)
# Requirement already satisfied: numpy>=1.22.5 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from chromadb) (1.26.4)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from fastapi>=0.95.2->chromadb) (0.27.0)
# Requirement already satisfied: coloredlogs in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: packaging in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb) (23.2)
# Requirement already satisfied: protobuf in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb) (4.25.4)
# Requirement already satisfied: sympy in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.2)
# Requirement already satisfied: six>=1.5 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from posthog>=2.4.0->chromadb) (1.16.0)
# Requirement already satisfied: monotonic>=1.5 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: python-dateutil>2.1 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from posthog>=2.4.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: certifi in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from pulsar-client>=3.1.0->chromadb) (2024.7.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from pydantic>=1.9->chromadb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from pydantic>=1.9->chromadb) (2.14.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from requests>=2.28->chromadb) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from requests>=2.28->chromadb) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from requests>=2.28->chromadb) (2.1.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from tokenizers>=0.13.2->chromadb) (0.24.5)
# Requirement already satisfied: click>=8.0.0 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from typer>=0.9.0->chromadb) (13.7.1)
# Requirement already satisfied: h11>=0.8 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from uvicorn>=0.18.3->uvicorn[standard]>=0.18.3->chromadb) (0.14.0)
# Requirement already satisfied: httptools>=0.5.0 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (6.0.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.19.0)
# Requirement already satisfied: watchfiles>=0.13 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.23.0)
# Requirement already satisfied: websockets>=10.4 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (12.0)
# Requirement already satisfied: filelock in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.6.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (2.15.1)
# Requirement already satisfied: anyio<5,>=3.4.0 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from starlette<0.28.0,>=0.27.0->fastapi>=0.95.2->chromadb) (4.2.0)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi>=0.95.2->chromadb) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb) (0.1.2)
# Requirement already satisfied: langchain in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (0.2.13)
# Requirement already satisfied: PyYAML>=5.3 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from langchain) (2.0.32)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from langchain) (3.10.3)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.30 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from langchain) (0.2.30)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from langchain) (0.2.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from langchain) (0.1.99)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from langchain) (2.5.3)
# Requirement already satisfied: requests<3,>=2 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from langchain) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.3.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.30->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.30->langchain) (23.2)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.30->langchain) (4.11.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.7)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from pydantic<3,>=1->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from pydantic<3,>=1->langchain) (2.14.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from requests<3,>=2->langchain) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from requests<3,>=2->langchain) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from requests<3,>=2->langchain) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from requests<3,>=2->langchain) (2024.7.4)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.30->langchain) (2.1)
# Requirement already satisfied: langchain-openai in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (0.1.21)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.29 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from langchain-openai) (0.2.30)
# Requirement already satisfied: openai<2.0.0,>=1.40.0 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from langchain-openai) (1.40.6)
# Requirement already satisfied: tiktoken<1,>=0.7 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from langchain-openai) (0.7.0)
# Requirement already satisfied: PyYAML>=5.3 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.29->langchain-openai) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.29->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.29->langchain-openai) (0.1.99)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.29->langchain-openai) (23.2)
# Requirement already satisfied: pydantic<3,>=1 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.29->langchain-openai) (2.5.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.29->langchain-openai) (8.5.0)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.29->langchain-openai) (4.11.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (1.8.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (0.5.0)
# Requirement already satisfied: sniffio in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (4.65.0)
# Requirement already satisfied: regex>=2022.1.18 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.7.24)
# Requirement already satisfied: requests>=2.26.0 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2.31.0)
# Requirement already satisfied: idna>=2.8 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.40.0->langchain-openai) (3.4)
# Requirement already satisfied: certifi in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.40.0->langchain-openai) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.40.0->langchain-openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.40.0->langchain-openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.29->langchain-openai) (2.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.29->langchain-openai) (3.10.7)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from pydantic<3,>=1->langchain-core<0.3.0,>=0.2.29->langchain-openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from pydantic<3,>=1->langchain-core<0.3.0,>=0.2.29->langchain-openai) (2.14.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (2.1.0)
# Requirement already satisfied: numpy in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (1.26.4)
# Requirement already satisfied: openai in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (1.40.6)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from openai) (1.8.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from openai) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from openai) (0.5.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from openai) (2.5.3)
# Requirement already satisfied: sniffio in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from openai) (4.65.0)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from openai) (4.11.0)
# Requirement already satisfied: idna>=2.8 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai) (3.4)
# Requirement already satisfied: certifi in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (2.14.6)
# Requirement already satisfied: pandas in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: pydantic in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (2.5.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from pydantic) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from pydantic) (2.14.6)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/huanglanzhiguan/miniconda3/lib/python3.12/site-packages (from pydantic) (4.11.0)

# %%
import os
import pandas as pd
import shutil
import random
import re
from collections import defaultdict
from openai import OpenAI
from io import StringIO
from langchain.schema import Document
from langchain.vectorstores.chroma import Chroma
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain.prompts import ChatPromptTemplate

# %% [markdown]
# # Step 2: Generating Real Estate Listings

# %%
OPENAI_API_KEY = 'YOUR_OPENAI_API_KEY'
MODEL_NAME = 'gpt-3.5-turbo'
os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY
client = OpenAI(api_key=OPENAI_API_KEY)
openai_embedder = OpenAIEmbeddings()

# %%
prompt='''
Generate a detailed CSV file containing information on 20 unique real estate listings. Each listing should be organized into the following columns:

Neighborhood: The specific neighborhood of the property, e.g., "Green Oaks."
Price: The market price listed in USD, the type is integer, formatted as "$800,000."
Bedrooms: The total number of bedrooms, the type is integer, e.g., 3.
Bathrooms: The total number of bathrooms, the type is integer, e.g., 2.
House Size: The square footage of the property, the type is integer, e.g., "2,000 sqft."
For each property, provide a descriptive paragraph that highlights its unique features and amenities. Emphasize sustainable elements such as energy-efficient appliances, solar panels, sustainable materials, and garden spaces.

Example Listing Format:
Neighborhood,Price,Bedrooms,Bathrooms,House Size,Description
Green Oaks,"$800,000",3,2,"2,000 sqft","Welcome to this eco-friendly oasis nestled in the heart of Green Oaks. This charming 3-bedroom, 2-bathroom home boasts energy-efficient features such as solar panels and a well-insulated structure. Natural light floods the living spaces, highlighting the beautiful hardwood floors and eco-conscious finishes. The open-concept kitchen and dining area lead to a spacious backyard with a vegetable garden, perfect for the eco-conscious family. Embrace sustainable living without compromising on style in this Green Oaks gem."

Description Guidance:
Reflect the property's appeal, including its eco-friendly design and inviting living spaces.
Capture the neighborhood's character, emphasizing community elements such as organic grocery stores, parks, cafés, public transport accessibility, and environmental initiatives.
Ensure the CSV document has clear headers for each column, following the given example. Provide 20 unique listings, each showcasing distinct properties.
'''

messages = [{"role": "system", "content": f"{prompt}"}]
response = client.chat.completions.create(model=MODEL_NAME, messages=messages)
content = response.choices[0].message.content
print(content)

messages.append({"role": "assistant", "content": content})
# Out:
# Neighborhood,Price,Bedrooms,Bathrooms,House Size,Description
# Willow Creek,"$750,000",4,3,"2,500 sqft","Discover this modern 4-bedroom, 3-bathroom home in the peaceful Willow Creek neighborhood. The house features energy-efficient appliances, a smart thermostat, and LED lighting throughout. The spacious backyard is perfect for entertaining, complete with a rainwater harvesting system and a variety of fruit trees. Enjoy sustainable living with style in Willow Creek."
# Riverfront Estates,"$1,200,000",5,4,"3,800 sqft","Luxury meets sustainability in this 5-bedroom, 4-bathroom home in Riverfront Estates. This property boasts solar panels, geothermal heating, and cooling systems, as well as reclaimed wood flooring. The gourmet kitchen overlooks a serene riverfront, and the home includes a rooftop garden for growing your own herbs and vegetables. Experience eco-luxury living at its finest in Riverfront Estates."
# Sunnydale Heights,"$680,000",3,2,"1,800 sqft","Nestled in the vibrant community of Sunnydale Heights, this 3-bedroom, 2-bathroom home features a LEED Platinum certification for its sustainable design. Enjoy natural light, bamboo flooring, and a rain garden in the backyard. The neighborhood offers easy access to local farmers markets, hiking trails, and eco-friendly cafes. Live green in Sunnydale Heights."
# Maple Grove,"$820,000",4,3,"2,300 sqft","Welcome to this 4-bedroom, 3-bathroom home in Maple Grove, designed with sustainability in mind. The house includes energy-efficient windows, a programmable irrigation system for the garden, and a composting station. Maple Grove is known for its community gardens and bike-friendly streets. Embrace eco-conscious living in Maple Grove."
# Pine Ridge,"$900,000",5,3,"2,700 sqft","Discover a sustainable oasis in Pine Ridge with this 5-bedroom, 3-bathroom home. The property features a green roof, passive solar design, and recycled glass countertops. The spacious backyard offers a vegetable garden, fruit trees, and a solar-powered outdoor kitchen. Pine Ridge is a nature lover's paradise with hiking trails and wildlife conservation efforts."
# Harbor View,"$950,000",4,4,"3,000 sqft","Experience waterfront living in this 4-bedroom, 4-bathroom home in Harbor View. Energy-efficient features include a wind turbine, rainwater collection system, and eco-friendly bamboo flooring. The property boasts a private dock and beach access, perfect for water sports enthusiasts. Live sustainably by the sea in Harbor View."
# Golden Hills,"$730,000",3,2,"1,600 sqft","Located in the Rolling Green community of Golden Hills, this 3-bedroom, 2-bathroom home offers eco-friendly living. Enjoy energy-efficient appliances, a xeriscaped front yard, and a backyard oasis with a solar-powered hot tub. Golden Hills is known for its community events promoting sustainable practices and conservation efforts. Live green in Golden Hills."
# Redwood Grove,"$840,000",4,3,"2,400 sqft","Embrace nature in this 4-bedroom, 3-bathroom home nestled in the Redwood Grove neighborhood. The property features a rainwater harvesting system, a green living wall, and reclaimed wood accents. Enjoy the tranquil backyard with a meditation garden and composting area. Redwood Grove is a sanctuary for eco-conscious living."
# Sunset Terrace,"$780,000",3,2,"1,700 sqft","Discover sustainable living in Sunset Terrace with this 3-bedroom, 2-bathroom home. The house includes energy-efficient windows, a smart irrigation system, and a rooftop solar panel array. Sunset Terrace offers easy access to public transportation, organic markets, and community gardens. Experience eco-friendly urban living in Sunset Terrace."
# Meadowbrook Springs,"$890,000",5,4,"2,800 sqft","Escape to this 5-bedroom, 4-bathroom home in the Meadowbrook Springs community. Sustainable features include a gray water recycling system, eco-friendly cabinetry, and a native plant garden. The large backyard is perfect for hosting gatherings and includes a fire pit fueled by reclaimed wood. Live green in Meadowbrook Springs."
# Sage Ridge,"$990,000",4,3,"2,500 sqft","This 4-bedroom, 3-bathroom home in Sage Ridge offers sustainable luxury. Features include a solar water heating system, energy-efficient appliances, and a drought-tolerant landscaped yard. The neighborhood promotes environmental initiatives such as composting workshops and community clean-up events. Live in harmony with nature in Sage Ridge."
# Springfield Heights,"$710,000",3,2,"1,600 sqft","Experience eco-chic living in Springfield Heights with this 3-bedroom, 2-bathroom home. The property boasts a green roof, sustainable bamboo flooring, and energy-efficient lighting. Enjoy the community garden and nearby hiking trails in the green-friendly neighborhood. Springfield Heights is a haven for those seeking a sustainable lifestyle."
# Cedar Valley,"$820,000",4,3,"2,200 sqft","Settle into this 4-bedroom, 3-bathroom home in the serene neighborhood of Cedar Valley. The house features a passive solar design, energy-efficient HVAC system, and recycled glass countertops. The backyard oasis includes a rain garden and organic vegetable beds. Embrace sustainable living in Cedar Valley."
# Ocean Breeze,"$1,150,000",5,4,"3,500 sqft","Live in luxury in this 5-bedroom, 4-bathroom home in Ocean Breeze. Sustainable elements include a rooftop solar panel system, energy-efficient windows, and bamboo flooring. The property offers ocean views and a private garden with a variety of edible plants. Ocean Breeze is a sustainable paradise by the sea."
# Stonebridge Park,"$680,000",3,2,"1,800 sqft","Discover this charming 3-bedroom, 2-bathroom home in the eco-friendly neighborhood of Stonebridge Park. The house features a tankless water heater, Energy Star appliances, and a backyard composting bin. Stonebridge Park is known for its community-supported agriculture programs and walking trails. Embrace sustainable living in Stonebridge Park."
# Majestic Hills,"$830,000",4,3,"2,300 sqft","Welcome home to this 4-bedroom, 3-bathroom property in Majestic Hills, designed with sustainability in mind. The house boasts an energy-efficient HVAC system, a rainwater harvesting system, and sustainable bamboo flooring. Majestic Hills offers community events focused on renewable energy and conservation efforts. Live green in Majestic Hills."
# Whispering Pines,"$720,000",3,2,"1,700 sqft","Nestled in the Whispering Pines neighborhood, this 3-bedroom, 2-bathroom home offers sustainable living at its best. Features include a solar water heating system, drought-resistant landscaping, and a garden with raised beds for organic gardening. Whispering Pines is a nature lover's dream with green spaces and community initiatives promoting environmental stewardship."
# Rosewood Estates,"$960,000",5,4,"2,900 sqft","Luxury meets sustainability in this 5-bedroom, 4-bathroom home in Rosewood Estates. The property features a geothermal heating and cooling system, energy-efficient lighting, and a vegetable garden with a composting station. Rosewood Estates offers a green lifestyle with nearby parks, bike paths, and organic markets. Live sustainably in Rosewood Estates."
# Lakeside Haven,"$880,000",4,3,"2,600 sqft","This 4-bedroom, 3-bathroom home in Lakeside Haven offers a tranquil retreat with sustainable features. Enjoy a solar panel system, eco-friendly flooring, and a backyard oasis with a rain barrel collection system. Lakeside Haven is close to walking trails, community lakes, and eco-conscious amenities. Embrace green living in Lakeside Haven."

# %%
# Use StringIO to simulate a file object from the string data
data_io = StringIO(content.strip())
# Create a DataFrame
df = pd.read_csv(data_io)
# Display the DataFrame
df.head()
# Out:
#          Neighborhood       Price  Bedrooms  Bathrooms  House Size  \
# 0        Willow Creek    $750,000         4          3  2,500 sqft
# 1  Riverfront Estates  $1,200,000         5          4  3,800 sqft
# 2   Sunnydale Heights    $680,000         3          2  1,800 sqft
# 3         Maple Grove    $820,000         4          3  2,300 sqft
# 4          Pine Ridge    $900,000         5          3  2,700 sqft
#
#                                          Description
# 0  Discover this modern 4-bedroom, 3-bathroom hom...
# 1  Luxury meets sustainability in this 5-bedroom,...
# 2  Nestled in the vibrant community of Sunnydale ...
# 3  Welcome to this 4-bedroom, 3-bathroom home in ...
# 4  Discover a sustainable oasis in Pine Ridge wit...

# %% [markdown]
# # Step 3: Storing Listings in a Vector Database

# %%
# DB configuration
DB_PATH = "db"

if os.path.exists(DB_PATH):
    shutil.rmtree(DB_PATH)
    
documents = []
for index, row in df.iterrows():
    documents.append(Document(page_content=row['Description'], metadata={'id': str(index)}))

# Save to vector database
db = Chroma.from_documents(documents, openai_embedder, persist_directory=DB_PATH)
print(f"{len(documents)} documents saved")
# Out:
# 19 documents saved

# %% [markdown]
# # Step 4: Building the User Preference Interface

# %%
questions = [   
                "How big do you want your house to be?", 
                "What are 3 most important things for you in choosing this property?", 
                "Which amenities would you like?", 
                "Which transportation options are important to you?",
                "How urban do you want your neighborhood to be?",   
            ]
answers = [
    "A comfortable three-bedroom house with a spacious kitchen and a cozy living room.",
    "A quiet neighborhood, good local schools, and convenient shopping options.",
    "A backyard for gardening, a two-car garage, and a modern, energy-efficient heating system.",
    "Easy access to a reliable bus line, proximity to a major highway, and bike-friendly roads.",
    "A balance between suburban tranquility and access to urban amenities like restaurants and theaters."
    ]

def parse_preferences(answers):
    structured_preferences = defaultdict(lambda: defaultdict(list))

    for answer in answers:
        # Bedrooms and house size
        bedrooms_match = re.search(r'\b(\w+-bedroom)\b', answer, re.IGNORECASE)
        if bedrooms_match:
            structured_preferences['house']['bedrooms'].append(bedrooms_match.group(1))
        
        # Kitchen and living room
        if 'kitchen' in answer:
            structured_preferences['house']['features'].append('spacious kitchen')
        if 'living room' in answer:
            structured_preferences['house']['features'].append('cozy living room')

        # Neighborhood and schools
        if 'quiet neighborhood' in answer:
            structured_preferences['location']['neighborhood'].append('quiet')
        if 'local schools' in answer:
            structured_preferences['location']['schools'].append('good')
        if 'shopping options' in answer:
            structured_preferences['location']['shopping'].append('convenient')

        # Outdoor and garage features
        if 'backyard' in answer:
            structured_preferences['house']['features'].append('backyard for gardening')
        if 'garage' in answer:
            structured_preferences['house']['features'].append('two-car garage')
        if 'energy-efficient heating system' in answer:
            structured_preferences['house']['features'].append('modern energy-efficient heating system')

        # Transportation
        if re.search(r'\bbus line\b', answer, re.IGNORECASE):
            structured_preferences['transport']['access'].append('bus line')
        if 'major highway' in answer:
            structured_preferences['transport']['access'].append('major highway')
        if 'bike-friendly roads' in answer:
            structured_preferences['transport']['features'].append('bike-friendly roads')

        # Urban settings
        if 'suburban tranquility' in answer:
            structured_preferences['location']['urban balance'].append('suburban tranquility')
        if 'urban amenities' in answer:
            structured_preferences['location']['urban balance'].append('urban amenities')
        if 'restaurants and theaters' in answer:
            structured_preferences['location']['amenities'].append('restaurants and theaters')

    return structured_preferences

def construct_query_text(structured_preferences):
    query_parts = []

    # House size and features
    if structured_preferences['house']['bedrooms']:
        bedrooms = ', '.join(structured_preferences['house']['bedrooms'])
        query_parts.append(f"a {bedrooms} house")
    
    if structured_preferences['house']['features']:
        features = ', '.join(structured_preferences['house']['features'])
        query_parts.append(f"with {features}")

    # Neighborhood and location preferences
    if structured_preferences['location']['neighborhood']:
        neighborhood = ', '.join(structured_preferences['location']['neighborhood'])
        query_parts.append(f"in a {neighborhood} neighborhood")
    
    if structured_preferences['location']['schools']:
        schools = ', '.join(structured_preferences['location']['schools'])
        query_parts.append(f"with {schools} local schools")
        
    if structured_preferences['location']['shopping']:
        shopping = ', '.join(structured_preferences['location']['shopping'])
        query_parts.append(f"and {shopping} shopping options")
    
    # Transportation preferences
    if structured_preferences['transport']['access']:
        transport_access = ', '.join(structured_preferences['transport']['access'])
        query_parts.append(f"with access to a {transport_access}")
    
    if structured_preferences['transport']['features']:
        transport_features = ', '.join(structured_preferences['transport']['features'])
        query_parts.append(f"and features like {transport_features}")

    # Urban balance and amenities
    if structured_preferences['location']['urban balance']:
        urban_balance = ', '.join(structured_preferences['location']['urban balance'])
        query_parts.append(f"balancing {urban_balance}")

    if structured_preferences['location']['amenities']:
        amenities = ', '.join(structured_preferences['location']['amenities'])
        query_parts.append(f"and nearby {amenities}")

    # Construct the final query text
    query_text = "I'm looking for " + ' '.join(query_parts) + "."
    return query_text

idx = random.randint(0, 4)
question = questions[idx]
answer = answers[idx]
print(f"Question: {question}")
print(f"Answer: {answer}")

ret = parse_preferences([answer])
query = construct_query_text(ret)
print(query)
# Out:
# Question: How urban do you want your neighborhood to be?
# Answer: A balance between suburban tranquility and access to urban amenities like restaurants and theaters.
# I'm looking for balancing suburban tranquility, urban amenities and nearby restaurants and theaters.

# %% [markdown]
# # Step 5&6: Searching Based on Preferences & Personalizing Listing Descriptions

# %%
# Get a random question
similarity_threshold = 0.6

template = """
Reply to the question based on the following context from database:
====================================

{context}

====================================

The context is retrieved from the database based on the user's preferences.
It's already sorted. The most relevant context is at the top.
Give a clear and reasonable response to the user who wants to buy a house based on the context provided above.
For each retrieved listing, you should also augment the description,
tailoring it to resonate with the buyer’s specific preferences.
This involves subtly emphasizing aspects of the property that align with what the buyer is looking for.
---

The preference from the user is:
{question}
"""

# Search the DB.
results = db.similarity_search_with_relevance_scores(query, k=3)
if len(results) == 0 or results[0][1] < similarity_threshold:
    print("Failed to find any matching results.")
else:
    context_text = "\n\n====================================\n\n".join([doc.page_content for doc, _score in results])
    prompt_template = ChatPromptTemplate.from_template(template)
    prompt = prompt_template.format(context=context_text, question=query)
    llm = ChatOpenAI()
    response_text = llm.predict(prompt)
    print(f"PROMPT:\n{prompt}")
    print(f"Response: {response_text}")
# Out:
# PROMPT:
# Human:
# Reply to the question based on the following context from database:
# ====================================
#
# Discover sustainable living in Sunset Terrace with this 3-bedroom, 2-bathroom home. The house includes energy-efficient windows, a smart irrigation system, and a rooftop solar panel array. Sunset Terrace offers easy access to public transportation, organic markets, and community gardens. Experience eco-friendly urban living in Sunset Terrace.
#
# ====================================
#
# Experience eco-chic living in Springfield Heights with this 3-bedroom, 2-bathroom home. The property boasts a green roof, sustainable bamboo flooring, and energy-efficient lighting. Enjoy the community garden and nearby hiking trails in the green-friendly neighborhood. Springfield Heights is a haven for those seeking a sustainable lifestyle.
#
# ====================================
#
# Located in the Rolling Green community of Golden Hills, this 3-bedroom, 2-bathroom home offers eco-friendly living. Enjoy energy-efficient appliances, a xeriscaped front yard, and a backyard oasis with a solar-powered hot tub. Golden Hills is known for its community events promoting sustainable practices and conservation efforts. Live green in Golden Hills.
#
# ====================================
#
# The context is retrieved from the database based on the user's preferences.
# It's already sorted. The most relevant context is at the top.
# Give a clear and reasonable response to the user who wants to buy a house based on the context provided above.
# For each retrieved listing, you should also augment the description,
# tailoring it to resonate with the buyer’s specific preferences.
# This involves subtly emphasizing aspects of the property that align with what the buyer is looking for.
# ---
#
# The preference from the user is:
# I'm looking for balancing suburban tranquility, urban amenities and nearby restaurants and theaters.
#
# Response: Based on your preferences for balancing suburban tranquility with urban amenities and nearby restaurants and theaters, I would recommend exploring the eco-friendly living options in Sunset Terrace. This 3-bedroom, 2-bathroom home offers sustainable living with energy-efficient windows, a smart irrigation system, and a rooftop solar panel array. Additionally, you'll have easy access to public transportation, organic markets, and community gardens in the neighborhood. Sunset Terrace provides the perfect blend of eco-chic living and urban convenience, making it an ideal choice for your lifestyle.
